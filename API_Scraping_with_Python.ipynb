# %% [markdown]
# <a href="https://colab.research.google.com/github/miguroi/study/blob/main/API_Scraping_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 1: API Scraping Exchange Rates

# %%
# Import library
import requests

# Where USD is the base currency you want to use
# Change 'YOUR_API_KEY' with Your API KEY

url = 'https://v6.exchangerate-api.com/v6/12838347eab73185768f8c35/latest/USD'

# Making our request
response = requests.get(url)
data = response.json()

# Your JSON object
data
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1735689601,
#  'time_last_update_utc': 'Wed, 01 Jan 2025 00:00:01 +0000',
#  'time_next_update_unix': 1735776001,
#  'time_next_update_utc': 'Thu, 02 Jan 2025 00:00:01 +0000',
#  'base_code': 'USD',
#  'conversion_rates': {'USD': 1,
#   'AED': 3.6725,
#   'AFN': 70.5329,
#   'ALL': 94.423,
#   'AMD': 396.7146,
#   'ANG': 1.79,
#   'AOA': 920.6222,
#   'ARS': 1032.5,
#   'AUD': 1.6133,
#   'AWG': 1.79,
#   'AZN': 1.6999,
#   'BAM': 1.8851,
#   'BBD': 2.0,
#   'BDT': 119.5888,
#   'BGN': 1.8849,
#   'BHD': 0.376,
#   'BIF': 2948.2192,
#   'BMD': 1.0,
#   'BND': 1.3643,
#   'BOB': 6.9408,
#   'BRL': 6.181,
#   'BSD': 1.0,
#   'BTN': 85.6429,
#   'BWP': 13.9679,
#   'BYN': 3.3523,
#   'BZD': 2.0,
#   'CAD': 1.4382,
#   'CDF': 2849.8544,
#   'CHF': 0.9065,
#   'CLP': 994.5205,
#   'CNY': 7.3159,
#   'COP': 4410.8341,
#   'CRC': 509.8514,
#   'CUP': 24.0,
#   'CVE': 106.2792,
#   'CZK': 24.2682,
#   'DJF': 177.721,
#   'DKK': 7.1891,
#   'DOP': 61.1771,
#   'DZD': 135.7076,
#   'EGP': 50.838,
#   'ERN': 15.0,
#   'ETB': 127.0268,
#   'EUR': 0.9639,
#   'FJD': 2.3259,
#   'FKP': 0.7985,
#   'FOK': 7.1891,
#   'GBP': 0.7985,
#   'GEL': 2.811,
#   'GGP': 0.7985,
#   'GHS': 14.8378,
#   'GIP': 0.7985,
#   'GMD': 72.5912,
#   'GNF': 8622.0284,
#   'GTQ': 7.7202,
#   'GYD': 209.236,
#   'HKD': 7.7674,
#   'HNL': 25.4466,
#   'HRK': 7.2621,
#   'HTG': 130.683,
#   'HUF': 396.4531,
#   'IDR': 16219.2466,
#   'ILS': 3.6437,
#   'IMP': 0.7985,
#   'INR': 85.6431,
#   'IQD': 1311.0276,
#   'IRR': 41965.6045,
#   'ISK': 138.3572,
#   'JEP': 0.7985,
#   'JMD': 156.2606,
#   'JOD': 0.709,
#   'JPY': 157.1098,
#   'KES': 129.2668,
#   'KGS': 86.9792,
#   'KHR': 4037.6598,
#   'KID': 1.6137,
#   'KMF': 474.1844,
#   'KRW': 1474.816,
#   'KWD': 0.3084,
#   'KYD': 0.8333,
#   'KZT': 524.8458,
#   'LAK': 21921.0862,
#   'LBP': 89500.0,
#   'LKR': 293.3181,
#   'LRD': 184.0657,
#   'LSL': 18.8508,
#   'LYD': 4.9151,
#   'MAD': 10.121,
#   'MDL': 18.4077,
#   'MGA': 4706.3848,
#   'MKD': 59.0327,
#   'MMK': 2101.029,
#   'MNT': 3431.269,
#   'MOP': 8.0004,
#   'MRU': 39.8862,
#   'MUR': 47.042,
#   'MVR': 15.4719,
#   'MWK': 1739.4278,
#   'MXN': 20.788,
#   'MYR': 4.4668,
#   'MZN': 63.9594,
#   'NAD': 18.8508,
#   'NGN': 1534.2343,
#   'NIO': 36.849,
#   'NOK': 11.3621,
#   'NPR': 137.0286,
#   'NZD': 1.7855,
#   'OMR': 0.3845,
#   'PAB': 1.0,
#   'PEN': 3.7578,
#   'PGK': 4.0595,
#   'PHP': 58.0686,
#   'PKR': 279.2318,
#   'PLN': 4.1206,
#   'PYG': 7860.3703,
#   'QAR': 3.64,
#   'RON': 4.7842,
#   'RSD': 112.4259,
#   'RUB': 109.48,
#   'RWF': 1399.8731,
#   'SAR': 3.75,
#   'SBD': 8.499,
#   'SCR': 14.2617,
#   'SDG': 544.5716,
#   'SEK': 11.0433,
#   'SGD': 1.3643,
#   'SHP': 0.7985,
#   'SLE': 22.9188,
#   'SLL': 22918.8259,
#   'SOS': 571.8159,
#   'SRD': 35.5952,
#   'SSP': 3893.2939,
#   'STN': 23.6144,
#   'SYP': 12979.8121,
#   'SZL': 18.8508,
#   'THB': 34.2914,
#   'TJS': 10.922,
#   'TMT': 3.5007,
#   'TND': 3.1894,
#   'TOP': 2.4088,
#   'TRY': 35.3661,
#   'TTD': 6.7821,
#   'TVD': 1.6137,
#   'TWD': 32.8111,
#   'TZS': 2418.7576,
#   'UAH': 42.0423,
#   'UGX': 3684.5745,
#   'UYU': 43.8126,
#   'UZS': 12884.584,
#   'VES': 52.0271,
#   'VND': 25493.9298,
#   'VUV': 119.8011,
#   'WST': 2.8192,
#   'XAF': 632.2459,
#   'XCD': 2.7,
#   'XDR': 0.7652,
#   'XOF': 632.2459,
#   'XPF': 115.0185,
#   'YER': 249.7787,
#   'ZAR': 18.8509,
#   'ZMW': 27.9126,
#   'ZWL': 25.7985}}

# %%
# Import library
import pandas as pd

# %%
# Merubah json ke dataframe
data = pd.json_normalize(data)
data.head()
# Out:
#     result                          documentation  \
# 0  success  https://www.exchangerate-api.com/docs
#
#                              terms_of_use  time_last_update_unix  \
# 0  https://www.exchangerate-api.com/terms             1735689601
#
#               time_last_update_utc  time_next_update_unix  \
# 0  Wed, 01 Jan 2025 00:00:01 +0000             1735776001
#
#               time_next_update_utc base_code  conversion_rates.USD  \
# 0  Thu, 02 Jan 2025 00:00:01 +0000       USD                     1
#
#    conversion_rates.AED  ...  conversion_rates.WST  conversion_rates.XAF  \
# 0                3.6725  ...                2.8192              632.2459
#
#    conversion_rates.XCD  conversion_rates.XDR  conversion_rates.XOF  \
# 0                   2.7                0.7652              632.2459
#
#    conversion_rates.XPF  conversion_rates.YER  conversion_rates.ZAR  \
# 0              115.0185              249.7787               18.8509
#
#    conversion_rates.ZMW  conversion_rates.ZWL
# 0               27.9126               25.7985
#
# [1 rows x 170 columns]

# %%
# Mengecek column dan jumlahnya
data.columns
# Out:
# Index(['result', 'documentation', 'terms_of_use', 'time_last_update_unix',
#        'time_last_update_utc', 'time_next_update_unix', 'time_next_update_utc',
#        'base_code', 'conversion_rates.USD', 'conversion_rates.AED',
#        ...
#        'conversion_rates.WST', 'conversion_rates.XAF', 'conversion_rates.XCD',
#        'conversion_rates.XDR', 'conversion_rates.XOF', 'conversion_rates.XPF',
#        'conversion_rates.YER', 'conversion_rates.ZAR', 'conversion_rates.ZMW',
#        'conversion_rates.ZWL'],
#       dtype='object', length=170)

# %%
# Mengambil 8 kolom pertama
data1 = data.iloc[:, 0:8]
data1.head()
# Out:
#     result                          documentation  \
# 0  success  https://www.exchangerate-api.com/docs
#
#                              terms_of_use  time_last_update_unix  \
# 0  https://www.exchangerate-api.com/terms             1735689601
#
#               time_last_update_utc  time_next_update_unix  \
# 0  Wed, 01 Jan 2025 00:00:01 +0000             1735776001
#
#               time_next_update_utc base_code
# 0  Thu, 02 Jan 2025 00:00:01 +0000       USD

# %%
data1['key'] = 1
data1.head()
# Out:
#     result                          documentation  \
# 0  success  https://www.exchangerate-api.com/docs
#
#                              terms_of_use  time_last_update_unix  \
# 0  https://www.exchangerate-api.com/terms             1735689601
#
#               time_last_update_utc  time_next_update_unix  \
# 0  Wed, 01 Jan 2025 00:00:01 +0000             1735776001
#
#               time_next_update_utc base_code  key
# 0  Thu, 02 Jan 2025 00:00:01 +0000       USD    1

# %%
data1['time_last_update_utc'] = pd.to_datetime(data['time_last_update_utc'])
data1
# Out:
#     result                          documentation  \
# 0  success  https://www.exchangerate-api.com/docs
#
#                              terms_of_use  time_last_update_unix  \
# 0  https://www.exchangerate-api.com/terms             1735689601
#
#        time_last_update_utc  time_next_update_unix  \
# 0 2025-01-01 00:00:01+00:00             1735776001
#
#               time_next_update_utc base_code  key
# 0  Thu, 02 Jan 2025 00:00:01 +0000       USD    1

# %%
# from pytz import timezone
# wib = timezone('Asia/Jakarta')
# data1['time_last_update_utc'] = data1['time_last_update_utc'].astimezone(timezone('Asia/jakarta'))

# %%
# Mengambil kolom ke 9 - 170 untuk kemudian di transpose
data2 = data.iloc[:,8:].T
data2.head()
# Out:
#                              0
# conversion_rates.USD    1.0000
# conversion_rates.AED    3.6725
# conversion_rates.AFN   70.5329
# conversion_rates.ALL   94.4230
# conversion_rates.AMD  396.7146

# %%
# Menambah kolom baru 'key'
data2['key'] = 1
data2.head()
# Out:
#                              0  key
# conversion_rates.USD    1.0000    1
# conversion_rates.AED    3.6725    1
# conversion_rates.AFN   70.5329    1
# conversion_rates.ALL   94.4230    1
# conversion_rates.AMD  396.7146    1

# %%
# Merubah nama kolom '0' menjadi 'rate'
data2 = data2.rename(columns={0:'rate'})
data2.head()
# Out:
#                           rate  key
# conversion_rates.USD    1.0000    1
# conversion_rates.AED    3.6725    1
# conversion_rates.AFN   70.5329    1
# conversion_rates.ALL   94.4230    1
# conversion_rates.AMD  396.7146    1

# %%
# Merubah index menjadi column dengan nama 'currency'
data2['currency'] = data2.index
data2.head()
# Out:
#                           rate  key              currency
# conversion_rates.USD    1.0000    1  conversion_rates.USD
# conversion_rates.AED    3.6725    1  conversion_rates.AED
# conversion_rates.AFN   70.5329    1  conversion_rates.AFN
# conversion_rates.ALL   94.4230    1  conversion_rates.ALL
# conversion_rates.AMD  396.7146    1  conversion_rates.AMD

# %%
# Menghapus karakter 'conversion_rates.' di kolom currency
data2['currency'] = data2['currency'].str.replace(r'conversion_rates.', '', regex=True)
data2.head()
# Out:
#                           rate  key currency
# conversion_rates.USD    1.0000    1      USD
# conversion_rates.AED    3.6725    1      AED
# conversion_rates.AFN   70.5329    1      AFN
# conversion_rates.ALL   94.4230    1      ALL
# conversion_rates.AMD  396.7146    1      AMD

# %%
# Merubah posisi kolom
data2 = data2[['key','currency','rate']]
# Menghapus index
data2.reset_index(drop=True, inplace=True)
data2.head()
# Out:
#    key currency      rate
# 0    1      USD    1.0000
# 1    1      AED    3.6725
# 2    1      AFN   70.5329
# 3    1      ALL   94.4230
# 4    1      AMD  396.7146

# %%
data_merged = pd.merge(data1, data2, on='key')

# %%
data_merged.head()
# Out:
#     result                          documentation  \
# 0  success  https://www.exchangerate-api.com/docs
# 1  success  https://www.exchangerate-api.com/docs
# 2  success  https://www.exchangerate-api.com/docs
# 3  success  https://www.exchangerate-api.com/docs
# 4  success  https://www.exchangerate-api.com/docs
#
#                              terms_of_use  time_last_update_unix  \
# 0  https://www.exchangerate-api.com/terms             1735689601
# 1  https://www.exchangerate-api.com/terms             1735689601
# 2  https://www.exchangerate-api.com/terms             1735689601
# 3  https://www.exchangerate-api.com/terms             1735689601
# 4  https://www.exchangerate-api.com/terms             1735689601
#
#        time_last_update_utc  time_next_update_unix  \
# 0 2025-01-01 00:00:01+00:00             1735776001
# 1 2025-01-01 00:00:01+00:00             1735776001
# 2 2025-01-01 00:00:01+00:00             1735776001
# 3 2025-01-01 00:00:01+00:00             1735776001
# 4 2025-01-01 00:00:01+00:00             1735776001
#
#               time_next_update_utc base_code  key currency      rate
# 0  Thu, 02 Jan 2025 00:00:01 +0000       USD    1      USD    1.0000
# 1  Thu, 02 Jan 2025 00:00:01 +0000       USD    1      AED    3.6725
# 2  Thu, 02 Jan 2025 00:00:01 +0000       USD    1      AFN   70.5329
# 3  Thu, 02 Jan 2025 00:00:01 +0000       USD    1      ALL   94.4230
# 4  Thu, 02 Jan 2025 00:00:01 +0000       USD    1      AMD  396.7146

# %%
data_merged = data_merged[['time_last_update_utc','base_code','currency','rate']]
data_merged.head()
# Out:
#        time_last_update_utc base_code currency      rate
# 0 2025-01-01 00:00:01+00:00       USD      USD    1.0000
# 1 2025-01-01 00:00:01+00:00       USD      AED    3.6725
# 2 2025-01-01 00:00:01+00:00       USD      AFN   70.5329
# 3 2025-01-01 00:00:01+00:00       USD      ALL   94.4230
# 4 2025-01-01 00:00:01+00:00       USD      AMD  396.7146

# %%
data_merged.to_csv('exchange_rates.csv', index=False)
